# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from dotenv import load_dotenv
import os

load_dotenv()

PINECONE_API_KEY = os.environ.get("PINECONE_API_KEY")
PINECONE_CLOUD = os.environ.get("PINECONE_CLOUD")
PINECONE_REGION = os.environ.get("PINECONE_REGION")
MISTRALAI_API_KEY = os.environ.get("MISTRALAI_API_KEY")

# %%
import json

def json_to_markdown(input_file, output_file):
    with open(input_file, 'r') as f:
        data = json.load(f)
    
    with open(output_file, 'w') as f:
        for topic, qa_pairs in data.get("topics", {}).items():
            f.write(f"# {topic}\n")
            for i, qa in enumerate(qa_pairs, 1):
                f.write(f"## {qa['question']}\n")
                f.write(f"{qa['answer']}\n\n")

json_to_markdown('qa_pairs.json', 'qa_pairs.md')

# %%
from langchain.text_splitter import MarkdownHeaderTextSplitter

def chunk_markdown_with_headers(file_path):
    headers_to_split_on = [
        ("#", "Topic"),
        ("##", "Question")
    ]

    with open(file_path, 'r') as f:
        content = f.read()
    
    text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
    docs = text_splitter.split_text(content)
    return docs

separated_docs = chunk_markdown_with_headers('qa_pairs.md')
# print(separated_docs)

# %%
# def separate_questions_and_answers(docs):
#     questions = []
#     answers = []
    
#     for doc in docs:
#         if doc.metadata["Type"] == "Question":
#             questions.append(doc)
#         elif doc.metadata["Type"] == "Answer":
#             answers.append(doc)
    
#     return questions, answers

# questions, answers = separate_questions_and_answers(separated_docs)
# print(questions[0])

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

model_name = "sentence-transformers/all-mpnet-base-v2"
embeddings = HuggingFaceEmbeddings(model_name=model_name)

# doc_result = embeddings.embed_documents([answer.page_content for answer in separated_docs])
# print(doc_result[0])

# %%
from pinecone import Pinecone, ServerlessSpec
import time

pc = Pinecone(api_key=PINECONE_API_KEY)
spec = ServerlessSpec(cloud=PINECONE_CLOUD, region=PINECONE_REGION)

index_name = "bmp-rag"
dimension = len(embeddings.embed_query("test"))

if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=dimension,
        metric="cosine",
        spec=spec
    )
    while not pc.describe_index(index_name).status['ready']:
        time.sleep(1)

print("Index before upsert:")
print(pc.Index(index_name).describe_index_stats())
print("\n")
# Out:
# Index before upsert:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_documents(
    documents=separated_docs,
    index_name=index_name,
    embedding=embeddings,
    namespace="bmp-rag"
)

time.sleep(5)
print("Index after upsert:")
print(pc.Index(index_name).describe_index_stats())
print("\n")
time.sleep(2)
# Out:
# Index after upsert:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {'bmp-rag': {'vector_count': 2242}},
#  'total_vector_count': 2242}

# %%
def get_topics_from_json(input_file):
    with open(input_file, 'r') as f:
        data = json.load(f)
    topics = list(data.get("topics", {}).keys())
    return topics

topics = get_topics_from_json('qa_pairs.json')
topic_embeddings = [embeddings.embed_query(topic) for topic in topics]

# %%
import numpy as np
from sentence_transformers import util

def classify_query_to_topic(query):
    query_embedding = embeddings.embed_query(query)
    similarities = util.cos_sim(query_embedding, topic_embeddings)
    best_topic_index = np.argmax(similarities)
    return topics[best_topic_index]

# %%
index = pc.Index(index_name)
namespace = "bmp-rag"

for ids in index.list(namespace=namespace):
    query = index.query(
        id=ids[0], 
        namespace=namespace, 
        top_k=1,
        include_values=True,
        include_metadata=True
    )
    print(query)
    print("\n")
# Out:
# {'matches': [{'id': '000fb88f-fc5f-4bc2-9831-e38ca48e037d',
#               'metadata': {'Question': 'What is neuroplasticity?',
#                            'Topic': 'Neuroplasticity and Rehabilitation '
#                                     'Techniques',
#                            'text': "Neuroplasticity is the brain's ability to "
#                                    'reorganize and form new neural connections '
#                                    'in response to learning, experience, or '
#                                    'injury, allowing it to adapt and recover '
#                                    'functions.'},
#               'score': 1.0,
#               'values': [-0.0413839743,
#                          0.0171231963,
#                          -0.0207109395,
#                          -0.0172835253,
#                          0.0416762717,
#                          0.0366317146,
#                          -0.0428273827,
#                          0.0263376925,
#                          -0.0603138879,
#                          0.0387304276,
#                          0.0237543378,
#                          -0.00903828628,
#                          0.0144230453,
#                          0.0287542325,
#                          0.0885966942,
#                          -0.00713227503,
#                          0.0346163511,
#                          0.00922403671,
#                          0.0594894253,
#                          0.0141497049,
#                          -0.0176200308,
#                          -0.0598116964,
#                          -0.0503002629,
#                          -0.0210278705,
#                          -0.031661,
#                          -0.0428091101,
#                          0.0120179141,
#                          -0.0271917172,
#                          -0.0168646332,
#                          -0.0123611772,
#                          -0.0264322162,
#                          -0.0247667376,
#                          -0.0093927579,
#                          -0.0334452428,
#                          1.87048363e-06,
#                          -0.0189565942,
#                          -0.00397070311,
#                          -0.030462442,
#                          0.0442179963,
#                          0.020882966,
#                          0.0121209817,
#                          -0.00646162499,
#                          -0.01492004,
#                          0.0175627116,
#                          -0.00508491462,
#                          -0.0235538837,
#                          0.0186076052,
#                          0.0730466694,
#                          -0.0124034649,
#                          0.0167192984,
#                          0.0055019334,
#                          0.0315138,
#                          0.0229176283,
#                          -0.000106872722,
#                          0.0159344561,
#                          0.094475,
#                          -0.0135678612,
#                          -0.0370205827,
#                          -0.0340015776,
#                          -0.044441849,
#                          -0.00134341058,
#                          -0.0465161577,
#                          -0.00524849771,
#                          -0.00354705518,
#                          -0.00635177968,
#                          -0.0343111716,
#                          0.0636717454,
#                          -0.00418705028,
#                          -0.019539658,
#                          0.0286692157,
#                          0.0433259644,
#                          -7.13596e-05,
#                          0.0458691083,
#                          -0.0202058014,
#                          0.0539162569,
#                          -0.00201546052,
#                          -0.049873177,
#                          -0.0101607274,
#                          0.026682023,
#                          -0.03832151,
#                          -0.0163473506,
#                          -0.00695809396,
#                          0.0432565548,
#                          -0.00737787,
#                          0.0353311,
#                          -0.0267696399,
#                          0.0219276045,
#                          0.00354481256,
#                          -0.0104754018,
#                          -0.0355937332,
#                          0.071919769,
#                          0.0410748459,
#                          -0.0187649671,
#                          0.0171033572,
#                          0.000739104871,
#                          -0.00905689783,
#                          -0.0260223672,
#                          -0.00214868714,
#                          0.0273846593,
#                          0.0110032819,
#                          0.00949041732,
#                          -0.0171199907,
#                          -0.00166707218,
#                          0.0244591311,
#                          -0.0414812751,
#                          -0.000261639594,
#                          -0.0987820551,
#                          -0.0264738817,
#                          -0.032551378,
#                          -0.0620699376,
#                          -0.0137824621,
#                          -0.0186696611]}],
#  'namespace': 'bmp-rag',
#  'usage': {'read_units': 6}}
#
#
# {'matches': [{'id': '0a6e8252-774a-4b71-9a80-2cacb66d6dbe',
#               'metadata': {'Question': 'What are the ethical considerations in '
#                                        'integrating research into clinical '
#                                        'practice?',
#                            'Topic': 'Research and Practice Integration',
#                            'text': 'Ethical considerations include ensuring '
#                                    'client confidentiality, obtaining informed '
#                                    'consent for participation in research, and '
#                                    'applying research findings in a manner '
#                                    'that benefits clients without causing '
#                                    'harm.'},
#               'score': 1.0,
#               'values': [0.0286230519,
#                          0.0553176291,
#                          -0.0262414403,
#                          0.015754614,
#                          -0.0828865,
#                          0.0218729861,
#                          0.0392355397,
#                          0.0186370108,
#                          -0.0152349407,
#                          0.00751820067,
#                          0.00385226775,
#                          0.0130600818,
#                          -0.0161381736,
#                          -0.0394519493,
#                          -0.0459801853,
#                          0.0173145179,
#                          -0.0348166376,
#                          0.0192669407,
#                          0.0429796614,
#                          0.037792515,
#                          -0.00315277884,
#                          -0.0177579504,
#                          0.00141904701,
#                          -0.0120967859,
#                          0.0197546724,
#                          -0.0152848307,
#                          0.0071594175,
#                          0.0358673856,
#                          0.00822337624,
#                          -0.00872914121,
#                          0.00641097361,
#                          -0.00477163726,
#                          0.00347173098,
#                          -0.041468244,
#                          1.46033813e-06,
#                          -0.00724570639,
#                          -0.0463461131,
#                          0.0168997031,
#                          0.0134064239,
#                          -0.0273656771,
#                          0.0682341158,
#                          -0.0426862091,
#                          0.0331367776,
#                          0.00592416059,
#                          -0.0203894321,
#                          0.0430827811,
#                          0.0202314109,
#                          0.0104106721,
#                          -0.00407410506,
#                          0.0293957964,
#                          -0.00652309135,
#                          0.0288645811,
#                          -0.0372280255,
#                          0.0228822827,
#                          -0.0666237697,
#                          -0.00180998934,
#                          0.0103163822,
#                          -0.081551373,
#                          -0.0340339,
#                          0.0303584374,
#                          0.0148190334,
#                          -0.019593427,
#                          -0.0280162692,
#                          -0.00667508459,
#                          -0.035455972,
#                          -0.0647658333,
#                          -0.0199707095,
#                          -0.0556776486,
#                          0.0119832829,
#                          0.00762891537,
#                          0.0816718787,
#                          0.0453641154,
#                          0.0119491462,
#                          -0.0191060398,
#                          0.0093432432,
#                          0.00552440807,
#                          0.0169560071,
#                          -0.0102597112,
#                          0.0081334142,
#                          0.0085727293,
#                          0.0242446419,
#                          0.0281295963,
#                          -0.00788485538,
#                          0.0518299751,
#                          0.084062323,
#                          -0.029444091,
#                          -0.0299968757,
#                          -0.0235065203,
#                          -0.00454109441,
#                          -0.00496493932,
#                          0.0563083813,
#                          -0.0120809702,
#                          0.0144705139,
#                          0.0418761335,
#                          0.0198669489,
#                          0.0102945082,
#                          0.0446480587,
#                          0.0103825089,
#                          0.101573035,
#                          0.0477651022,
#                          -0.0220446531,
#                          -0.0184835028,
#                          0.0209962633,
#                          -0.0146869645,
#                          -0.0503183343,
#                          0.028679898,
#                          -0.0311058536,
#                          0.0218817759,
#                          -0.0312589109,
#                          0.00342580467,
#                          -0.0363496654,
#                          -0.0520477481,
#                          -0.00373866851,
#                          -0.0664572716,
#                          0.0561381355,
#                          -0.0221194811,
#                          -0.0389895327,
#                          0.0138918776,
#                          0.0298872646,
#                          -0.00299480627,
#                          -0.00930976,
#                          0.00536698522,
#                          -0.0542706065,
#                          0.0142303603,
#                          -0.00813799724,
#                          0.0836357176,
#                          -0.0425896943,
#                          0.017594764,
#                          -0.0399258435,
#                          -0.00747170532,
#                          0.0298604257,
#                          -0.0207275916,
#                          0.0107041588,
#                          -0.0134399729,
#                          -0.0251798946,
#                          0.0261600334,
#                          0.0280050598,
#                          -0.0260563418,
#                          -0.0215828605,
#                          0.00569987809,
#                          -0.0419785455,
#                          -0.0327505954,
#                          0.0403308608,
#                          0.00196696701,
#                          1.45180222e-34,
#                          -0.0144405933,
#                          0.0261863433,
#                          -0.0384428091,
#                          -0.0168271586,
#                          0.015501366,
#                          0.00602057343,
#                          -0.0404596,
#                          -0.0117859831,
#                          0.000279415719,
#                          0.0279908758,
#                          -0.0124520715]}],
#  'namespace': 'bmp-rag',
#  'usage': {'read_units': 6}}

# %%
from langchain_mistralai import ChatMistralAI
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain import hub

retrieval_qa_chat_prompt = hub.pull("langchain-ai/retrieval-qa-chat")

llm = ChatMistralAI(
    api_key=MISTRALAI_API_KEY,
    model="mistral-large-latest",
    temperature=0.0
)

def answer_with_knowledge(query):
    topic = classify_query_to_topic(query)
    print(topic)

    retriever = docsearch.as_retriever(
        search_type="similarity",
        search_kwargs={
            "k": 50,
            "filter": {"Topic": topic}
        }
    )

    combine_docs_chain = create_stuff_documents_chain(
        llm, retrieval_qa_chat_prompt
    )

    retrieval_chain = create_retrieval_chain(retriever, combine_docs_chain)
    
    answer_with_knowledge = retrieval_chain.invoke({"input": query})
    return answer_with_knowledge

# %%
new_query = "What is buspirone, and how is it different from benzodiazepines?"
corrected_query = llm.invoke("Just correct the grammar without explanation: " + new_query)
print(corrected_query.content)
answer_without_knowledge = llm.invoke(corrected_query.content)

print("\nAnswer without knowledge:\n\n", answer_without_knowledge.content)
print("\n")
time.sleep(2)
# Out:
# What is buspirone, and how does it differ from benzodiazepines?
#
# Answer without knowledge:
#
#  Buspirone is a medication primarily used to treat anxiety disorders. It belongs to a class of drugs known as azapirones and is distinct from benzodiazepines in several ways.
#
# ### Mechanism of Action
# - **Buspirone**: Acts as a partial agonist at serotonin 5-HT1A receptors. This means it binds to these receptors and partially activates them, which can help regulate serotonin levels in the brain. It also has some effects on dopamine receptors.
# - **Benzodiazepines**: Enhance the activity of the neurotransmitter GABA (gamma-aminobutyric acid) by binding to GABA-A receptors. This increases the inhibitory effects of GABA, leading to a calming effect on the brain.
#
# ### Onset and Duration of Action
# - **Buspirone**: Typically takes 2-4 weeks to reach its full therapeutic effect. It is not effective for immediate relief of anxiety symptoms.
# - **Benzodiazepines**: Generally have a rapid onset of action, often within minutes to hours, making them effective for acute anxiety relief.
#
# ### Side Effects
# - **Buspirone**: Common side effects include dizziness, headache, nausea, nervousness, and lightheadedness. It is generally considered to have fewer side effects compared to benzodiazepines.
# - **Benzodiazepines**: Common side effects include drowsiness, dizziness, memory problems, and cognitive impairment. They can also cause dependence and withdrawal symptoms with prolonged use.
#
# ### Dependence and Withdrawal
# - **Buspirone**: Has a lower risk of dependence and withdrawal symptoms compared to benzodiazepines. It is generally considered safer for long-term use.
# - **Benzodiazepines**: Have a higher risk of dependence and withdrawal symptoms, especially with prolonged use. Abrupt discontinuation can lead to severe withdrawal symptoms, including seizures.
#
# ### Indications
# - **Buspirone**: Primarily used for the treatment of generalized anxiety disorder (GAD). It is not effective for panic disorder or other specific anxiety disorders.
# - **Benzodiazepines**: Used for a variety of conditions, including generalized anxiety disorder, panic disorder, insomnia, and seizures. They are also used for pre-operative sedation and muscle relaxation.
#
# ### Drug Interactions
# - **Buspirone**: Has fewer drug interactions compared to benzodiazepines. However, it can interact with other serotonergic drugs, potentially leading to serotonin syndrome.
# - **Benzodiazepines**: Can interact with a wide range of medications, including alcohol, opioids, and other central nervous system depressants, leading to increased sedation and respiratory depression.
#
# ### Summary
# Buspirone and benzodiazepines are both used to treat anxiety, but they work through different mechanisms and have different profiles in terms of onset, side effects, dependence, and indications. Buspirone is generally considered safer for long-term use due to its lower risk of dependence and withdrawal symptoms, while benzodiazepines are more effective for acute anxiety relief but come with a higher risk of side effects and dependence.

# %%
new_query = "What is buspirone, and how is it different from benzodiazepines?"
corrected_query = llm.invoke("Just correct the grammar without explanation: " + new_query)
answer = answer_with_knowledge("Give me an elaborate answer to this query: " + corrected_query.content)

print("Answer with knowledge:\n\n", answer['answer'])
print("\nContext used:\n\n", answer['context'])
print("\n")
time.sleep(2)
# Out:
# Anxiolytics (benzodiazepines, buspirone)
# Answer with knowledge:
#
#  Buspirone is an anxiolytic medication primarily used to treat generalized anxiety disorder. It works by affecting serotonin receptors in the brain, specifically as a partial agonist at 5-HT1A receptors. This mechanism helps to reduce anxiety symptoms without the risk of dependence or addiction, which is a significant advantage over benzodiazepines.
#
# Benzodiazepines, on the other hand, are a class of drugs that enhance the effect of the neurotransmitter GABA, which inhibits brain activity and produces sedative and calming effects. Examples of benzodiazepines include alprazolam (Xanax), lorazepam (Ativan), and diazepam (Valium). They are commonly used to treat anxiety, insomnia, and seizure disorders.
#
# Here are the key differences between buspirone and benzodiazepines:
#
# 1. **Mechanism of Action**:
#    - Buspirone: Affects serotonin receptors (5-HT1A partial agonist).
#    - Benzodiazepines: Enhance the effect of GABA, leading to increased inhibition in the brain.
#
# 2. **Onset and Duration of Effects**:
#    - Buspirone: Takes 1 to 2 weeks to show noticeable effects in reducing anxiety. It is better suited for long-term management of generalized anxiety.
#    - Benzodiazepines: Work more quickly and are often used for immediate relief of anxiety or panic attacks, as well as for short-term insomnia treatment.
#
# 3. **Risk of Dependence and Addiction**:
#    - Buspirone: Has no risk of addiction or dependence.
#    - Benzodiazepines: Carry a risk of dependence and addiction, especially with long-term use or misuse. They are generally not recommended for long-term use due to the risk of tolerance, dependence, and withdrawal symptoms.
#
# 4. **Side Effects**:
#    - Buspirone: Side effects can include dizziness, headache, nausea, and nervousness, but they are generally mild.
#    - Benzodiazepines: Common side effects include drowsiness, dizziness, confusion, memory impairment, and coordination problems. Long-term use can result in cognitive impairment.
#
# 5. **Withdrawal**:
#    - Buspirone: Does not typically cause withdrawal symptoms.
#    - Benzodiazepines: Discontinuing abruptly can lead to withdrawal symptoms such as seizures, anxiety, and insomnia. A gradual tapering schedule is recommended.
#
# 6. **Use with Other Medications**:
#    - Buspirone: Can be used alongside benzodiazepines in some cases, but the combination should be managed carefully due to the risk of excessive sedation.
#    - Benzodiazepines: Combining with alcohol or other depressants increases the risk of severe sedation, respiratory depression, and overdose, which can be life-threatening.
#
# In summary, buspirone is a non-addictive anxiolytic that works through the serotonin system and is better suited for long-term anxiety management. Benzodiazepines, while effective for immediate anxiety relief and short-term insomnia treatment, carry risks of dependence, addiction, and cognitive impairment with long-term use.
#
# Context used:
#
#  [Document(id='07c21749-33e6-4f63-8f48-a76b73ee6ccb', metadata={'Question': 'What is buspirone, and how is it different from benzodiazepines?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Buspirone is an anxiolytic that works by affecting serotonin receptors in the brain, providing anxiety relief without the risk of dependence associated with benzodiazepines.'), Document(id='980822e2-bad2-4bed-a3f8-ebe151779772', metadata={'Question': 'Is buspirone effective for panic attacks?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Buspirone is typically less effective for panic attacks compared to benzodiazepines, as it works gradually and is better suited for generalized anxiety.'), Document(id='c74c5361-354f-4129-bf13-f1629f6db8db', metadata={'Question': 'What is the primary benefit of buspirone over benzodiazepines?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='The primary benefit of buspirone is that it has no risk of addiction or dependence, unlike benzodiazepines.'), Document(id='911f6999-a1a1-499d-bf50-93a28e537252', metadata={'Question': 'Can buspirone be combined with benzodiazepines?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Yes, buspirone can be used alongside benzodiazepines in some cases, but the combination should be managed carefully due to the risk of excessive sedation.'), Document(id='c47a941f-7ddd-4a91-bb52-d60c8bd5020b', metadata={'Question': 'Can buspirone be used for depression?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Buspirone is not typically used for depression but may be prescribed for anxiety disorders that coexist with depressive symptoms.'), Document(id='d50ba3d3-8188-48c1-bcd8-ae027e468320', metadata={'Question': 'What are the potential side effects of buspirone?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Side effects of buspirone can include dizziness, headache, nausea, and nervousness, though they are generally mild.'), Document(id='1d5f7e57-4b36-46f7-9d24-7311fda3788b', metadata={'Question': 'How quickly does buspirone work?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Buspirone typically takes 1 to 2 weeks to show noticeable effects in reducing anxiety.'), Document(id='0230818d-2ad7-451b-8a5e-cfea7188f8bb', metadata={'Question': 'What is the risk of addiction with benzodiazepines?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Benzodiazepines carry a risk of dependence and addiction, especially with long-term use or misuse.'), Document(id='9a386955-be00-4c0c-bb07-a61c24517f75', metadata={'Question': 'How do benzodiazepines work?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Benzodiazepines enhance the effect of the neurotransmitter GABA, which inhibits brain activity and produces sedative and calming effects.'), Document(id='9744ab3e-0619-47db-9475-f3447d68d12b', metadata={'Question': 'What are benzodiazepines used for?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Benzodiazepines are primarily used to treat anxiety, insomnia, and seizure disorders by producing a calming effect on the brain.'), Document(id='31653d32-d539-4aa5-b345-05ded797ca64', metadata={'Question': 'What are some examples of benzodiazepines?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Examples of benzodiazepines include alprazolam (Xanax), lorazepam (Ativan), and diazepam (Valium).'), Document(id='10c02625-ab8e-4029-8103-fa8c6d32dfe4', metadata={'Question': 'How do benzodiazepines affect sleep?', 'Topic': 'Anxiolytics (benzodiazepines, buspirone)'}, page_content='Benzodiazepines are often prescribed for short-term insomnia treatment, as they help with falling asleep and maintaining sleep.'), Document(id='f303dd75-083c-4b3a-8efa-92272822573e', metadata={'Question': 'Can benzodiazepines be taken for long-term anxiety treatment?', 'Topic': 'Anxiolytics (benzodiaz ...

# %%
import json
import numpy as np

def load_qa_data(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data['topics']

def retrieve_top_k_answers(query, k=5):
    topic = classify_query_to_topic(query)
    
    retriever = docsearch.as_retriever(
        search_type="similarity",
        search_kwargs={
            "k": k,
            "filter": {"Topic": topic}
        }
    )

    retrieved_docs = retriever.get_relevant_documents(query)

    top_k_answers = [doc.page_content for doc in retrieved_docs]

    return top_k_answers

def reciprocal_rank(results, ground_truth):
    for rank, result in enumerate(results, start=1):
        if result in ground_truth:
            return 1 / rank
    return 0

def average_precision(results, ground_truth):
    relevant_count = 0
    precision_sum = 0.0
    for rank, result in enumerate(results, start=1):
        if result in ground_truth:
            relevant_count += 1
            precision_sum += relevant_count / rank
    if relevant_count == 0:
        return 0
    return precision_sum / relevant_count

def mean_average_precision(all_results, all_ground_truths):
    ap_scores = [average_precision(results, gt) for results, gt in zip(all_results, all_ground_truths)]
    return np.mean(ap_scores)

def evaluate_chatbot(qa_data, retrieve_top_k_func, k=5, num_queries=300):
    all_results = []
    all_ranks = []
    queries = []
    ground_truths = []
    count = 0

    for topic, qa_pairs in qa_data.items():
        for qa in qa_pairs:
            queries.append(qa['question'])
            ground_truths.append([qa['answer']])
            count += 1
            if count >= num_queries:
                break
        if count >= num_queries:
            break
    
    for query, ground_truth in zip(queries, ground_truths):
        results = retrieve_top_k_func(query, k)
        all_results.append(results)
        rr = reciprocal_rank(results, ground_truth)
        all_ranks.append(rr)
    
    mrr = np.mean(all_ranks)
    map_score = mean_average_precision(all_results, ground_truths)
    
    return mrr, map_score

qa_data = load_qa_data('qa_pairs.json')

mrr, map_score = evaluate_chatbot(qa_data, retrieve_top_k_answers, k=5, num_queries=300)
print(f"Mean Reciprocal Rank (MRR): {mrr}")
print(f"Mean Average Precision (MAP): {map_score}")
# Out:
# Mean Reciprocal Rank (MRR): 0.512611111111111
# Mean Average Precision (MAP): 0.512611111111111
